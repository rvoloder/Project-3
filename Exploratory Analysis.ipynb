# %%
import pandas as pd

# %%
final_df = pd.read_json('tmdb_api_results_2000.json')
final_df.to_csv('Data/final_tmbd_data_2000.csv.gz', compression='gzip',index=False)

# %%
final_df_2 = pd.read_json('tmdb_api_results_2001.json')
final_df.to_csv('Data/final_tmbd_data_2001.csv.gz', compression='gzip',index=False)

# %%
year_2000 = pd.read_csv('Data/final_tmbd_data_2000.csv.gz')
year_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# ...

# %%
year_2001 = pd.read_csv('Data/final_tmbd_data_2001.csv.gz')
year_2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# ...

# %%
frames = [year_2000, year_2001]
all_years = pd.concat(frames)
all_years.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# ...

# %% [markdown]
# # How many movies had at least some valid financial information (values > 0 for budget OR revenue)?

# %%
(all_years['budget'] > 0.0).value_counts()
# Out:
# False    1898
# True      498
# Name: budget, dtype: int64

# %% [markdown]
# There were 498 movies (each) with valid information for budget.

# %% [markdown]
# # How many movies are there in each of the certification categories (G/PG/PG-13/R)?

# %%
all_years['certification'].value_counts()
# Out:
# R          424
# PG-13      166
# NR          58
# PG          56
# G           26
# NC-17        8
# Unrated      2
# Name: certification, dtype: int64

# %% [markdown]
# # What is the average revenue per certification category?

# %%
all_years.groupby('certification')['revenue'].mean()
# Out:
# certification
# G          6.482653e+07
# NC-17      0.000000e+00
# NR         3.095740e+06
# PG         4.780495e+07
# PG-13      7.428733e+07
# R          1.593628e+07
# Unrated    0.000000e+00
# Name: revenue, dtype: float64

# %% [markdown]
# # What is the average budget per certification category?

# %%
all_years.groupby('certification')['budget'].mean()
# Out:
# certification
# G          2.769231e+07
# NC-17      0.000000e+00
# NR         3.113796e+06
# PG         2.922857e+07
# PG-13      3.356024e+07
# R          9.818342e+06
# Unrated    0.000000e+00
# Name: budget, dtype: float64

# %%
all_years.to_csv('Data/tmdb_results_combined.csv.gz', compression = 'gzip', index = False)
